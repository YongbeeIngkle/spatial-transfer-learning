ss_r2_11 = [0.2042724951849271, 0.3539025685475481, 0.3852381740146913, 0.334175662, 0.4185262457121916, 0.1132123329251505, 0.1908668800931017, 0.34176101, 0.151880334, 0.3917977841170306, 0.3020286672844597, 0.4215087849798752, 0.2351267046358092, 0.4220253220345955, 0.2902762899909429, 0.3055703285120813, 0.2571230802904531, 0.3156768826575161, 0.3113074800752108, -0.03377795]
ss_r2_13 = [0.3272519842934055, 0.3596483767625954, 0.2886717384277086, 0.2744525025313705, 0.4263358361085794, 0.018306035, 0.1233869943144873, 0.364814665, 0.1501110154221137, 0.4142850390668386, 0.3339960507106174, 0.4484154272565726, 0.2877402589299427, 0.428004787, 0.3094186956836334, 0.316144447, 0.3345579081462023, 0.3963208194411622, 0.3806849723216915, 0.2314697243025043]
ss_r2_15 = [0.3732636774230078, 0.3078319268287947, 0.2722105302334936, 0.33511881678346067, 0.45361925789852775, 0.31218534465866243, 0.1769695545867105, 0.4801161029452162, 0.19346643201910485, 0.40682058351607453, 0.42247722497144413, 0.4289354867434432, 0.3649579748164491, 0.4598619767869452, 0.3063656048516443, 0.343005136, 0.3693241981391723, 0.3965619834945452, 0.4191450067219158, 0.19266003396130638]

# Calculate means and standard deviations for each list
means_eud = [sum(lst) / len(lst) for lst in [eud_list_5, eud_list_7, eud_list_9, eud_list_11, eud_list_13, eud_list_15]]
std_devs_eud = [((sum((x - mean) ** 2 for x in lst) / len(lst)) ** 0.5) for lst, mean in zip([eud_list_5, eud_list_7, eud_list_9, eud_list_11, eud_list_13, eud_list_15], means_eud)]

means_ss_r2 = [sum(lst) / len(lst) for lst in [ss_r2_5, ss_r2_7, ss_r2_9, ss_r2_11, ss_r2_13, ss_r2_15]]
std_devs_ss_r2 = [((sum((x - mean) ** 2 for x in lst) / len(lst)) ** 0.5) for lst, mean in zip([ss_r2_5, ss_r2_7, ss_r2_9, ss_r2_11, ss_r2_13, ss_r2_15], means_ss_r2)]

# Plot
plt.errorbar([3, 5, 7, 9, 11, 13, 15], means_eud, yerr=std_devs_eud, fmt='o', capsize=5, label='Euclidean Distance')
plt.errorbar([3, 5, 7, 9, 11, 13, 15], means_ss_r2, yerr=std_devs_ss_r2, fmt='o', capsize=5, color='red', label='R2 Scores')
plt.xlabel('List Index')
plt.ylabel('Mean Value')
plt.title('Error Bars for Lists')
plt.xticks([3, 5, 7, 9, 11, 13, 15])
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 27
#      24 std_devs_ss_r2 = [((sum((x - mean) ** 2 for x in lst) / len(lst)) ** 0.5) for lst, mean in zip([ss_r2_5, ss_r2_7, ss_r2_9, ss_r2_11, ss_r2_13, ss_r2_15], means_ss_r2)]
#      26 # Plot
# ---> 27 plt.errorbar([3, 5, 7, 9, 11, 13, 15], means_eud, yerr=std_devs_eud, fmt='o', capsize=5, label='Euclidean Distance')
#      28 plt.errorbar([3, 5, 7, 9, 11, 13, 15], means_ss_r2, yerr=std_devs_ss_r2, fmt='o', capsize=5, color='red', label='R2 Scores')
#      29 plt.xlabel('List Index')
#
# File ~/anaconda3/envs/shrey-env/lib/python3.11/site-packages/matplotlib/pyplot.py:3030, in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    3009 @_copy_docstring_and_deprecators(Axes.errorbar)
#    3010 def errorbar(
# ...

# %%
# Calculate means and standard deviations for each list
means = [sum(lst) / len(lst) for lst in [eud_r2_5, eud_r2_7, eud_r2_9, eud_r2_11, eud_r2_13, eud_r2_15]]
std_devs = [((sum((x - mean) ** 2 for x in lst) / len(lst)) ** 0.5) for lst, mean in zip([eud_r2_5, eud_r2_7, eud_r2_9, eud_r2_11, eud_r2_13, eud_r2_15], means)]

# Plot
plt.errorbar([5,7,9,11,13,15], means, yerr=std_devs, fmt='o', capsize=5)
plt.xlabel('No. of Sensors')
plt.ylabel('Mean Value')
plt.title('Eastern US as source dataset')
plt.xticks([5,7,9,11,13,15])
plt.grid(True)
plt.show()

# %%
###################### Optimal neighborhood measure [NNW, W-LDF, East source]######################

# %%
###################### R2 score ######################

from matplotlib.transforms import Affine2D

df_r2 = pd.DataFrame({'Monitors': ['5', '7', '9', '11'],
                            'L2 Distance': [0.178, 0.316, 0.344, 0.369],
                   'Spatial Similarity': [0.127, 0.235, 0.282, 0.310],
                    'Semantic Similarity': [0.247, 0.336, 0.378, 0.377]})

# df_r2 = pd.DataFrame({'Monitors': ['5', '7', '9', '11', '13'],
#                             'L2 Distance': [0.178, 0.316, 0.344, 0.369, 0.404],
#                    'Spatial Similarity': [0.127, 0.235, 0.282, 0.310, 0.332],
#                     'Semantic Similarity': [0.247, 0.336, 0.378, 0.377, 0.393]})


l2_err = np.array([0.138, 0.088, 0.120, 0.124])
spatial_err = np.array([0.355, 0.115, 0.087, 0.082])
semantic_err = np.array([0.113, 0.079, 0.090, 0.109])

# l2_err = np.array([0.138, 0.088, 0.120, 0.124, 0.084])
# spatial_err = np.array([0.355, 0.115, 0.087, 0.082, 0.079])
# semantic_err = np.array([0.113, 0.079, 0.090, 0.109, 0.095])


l2_err_min = df_r2['L2 Distance'].to_numpy() - l2_err
l2_err_max = df_r2['L2 Distance'].to_numpy() + l2_err

spatial_err_min = df_r2['Spatial Similarity'].to_numpy() - spatial_err
spatial_err_max = df_r2['Spatial Similarity'].to_numpy() + spatial_err

semantic_err_min = df_r2['Semantic Similarity'].to_numpy() - semantic_err
semantic_err_max = df_r2['Semantic Similarity'].to_numpy() + semantic_err


fig, ax = plt.subplots(figsize = (12, 8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


trans1 = Affine2D().translate(-0.1, 0.0) + ax.transData
trans2 = Affine2D().translate(+0.05, 0.0) + ax.transData
trans3 = Affine2D().translate(+0.2, 0.0) + ax.transData
trans4 = Affine2D().translate(+0.35, 0.0) + ax.transData

ax.errorbar('Monitors', 'L2 Distance', yerr=l2_err, data=df_r2,
             marker='o', capsize=8, color='blue', markersize=15, ls='none', alpha=0.9, linewidth=4, transform=trans1) 

ax.errorbar('Monitors', 'Spatial Similarity', yerr = spatial_err, data=df_r2, marker='s', capsize=8,
             color='red', markersize=15, ls='none', alpha=0.9, linewidth=4, transform=trans2) 

ax.errorbar('Monitors', 'Semantic Similarity', yerr = semantic_err, data=df_r2, marker='X', capsize=8,
             color='green',  markersize=15, ls='none', alpha=0.9, linewidth=4, transform=trans3) 


plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, prop={'size': 22})
plt.xlabel("Monitoring Stations", fontsize=26)
plt.xticks(fontsize=24)
plt.ylabel("R2 Score", fontsize=26)
plt.yticks(fontsize=24)
plt.show()

# %%
###################### RMSE score ######################

from matplotlib.transforms import Affine2D

df_rmse = pd.DataFrame({'Monitors': ['5', '7', '9', '11'],
                            'L2 Distance': [7.825, 7.162, 7.044, 6.874],
                   'Spatial Similarity': [7.978, 7.576, 7.391, 7.213],
                    'Semantic Similarity': [7.494, 7.061, 6.874, 6.838]})

# df_rmse = pd.DataFrame({'Monitors': ['5', '7', '9', '11', '13'],
#                             'L2 Distance': [7.825, 7.162, 7.044, 6.874, 6.695],
#                    'Spatial Similarity': [7.978, 7.576, 7.391, 7.213, 7.091],
#                     'Semantic Similarity': [7.494, 7.061, 6.874, 6.838, 6.750]})


l2_err = np.array([0.618, 0.501, 0.633, 0.614])
spatial_err = np.array([1.293, 0.590, 0.512, 0.530])
semantic_err = np.array([0.535, 0.490, 0.553, 0.599])

# l2_err = np.array([0.618, 0.501, 0.633, 0.614, 0.554])
# spatial_err = np.array([1.293, 0.590, 0.512, 0.530, 0.567])
# semantic_err = np.array([0.535, 0.490, 0.553, 0.599, 0.579])


l2_err_min = df_rmse['L2 Distance'].to_numpy() - l2_err
l2_err_max = df_rmse['L2 Distance'].to_numpy() + l2_err

spatial_err_min = df_rmse['Spatial Similarity'].to_numpy() - spatial_err
spatial_err_max = df_rmse['Spatial Similarity'].to_numpy() + spatial_err

semantic_err_min = df_rmse['Semantic Similarity'].to_numpy() - semantic_err
semantic_err_max = df_rmse['Semantic Similarity'].to_numpy() + semantic_err


fig, ax = plt.subplots(figsize = (12, 8))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


trans1 = Affine2D().translate(-0.1, 0.0) + ax.transData
trans2 = Affine2D().translate(+0.05, 0.0) + ax.transData
trans3 = Affine2D().translate(+0.2, 0.0) + ax.transData
trans4 = Affine2D().translate(+0.35, 0.0) + ax.transData

ax.errorbar('Monitors', 'L2 Distance', yerr=l2_err, data=df_rmse,
             marker='o', capsize=8, color='blue', markersize=15, ls='none', alpha=0.9, linewidth=4, transform=trans1) 

ax.errorbar('Monitors', 'Spatial Similarity', yerr = spatial_err, data=df_rmse, marker='s', capsize=8,
             color='red', markersize=15, ls='none', alpha=0.9, linewidth=4, transform=trans2) 

ax.errorbar('Monitors', 'Semantic Similarity', yerr = semantic_err, data=df_rmse, marker='X', capsize=8,
             color='green',  markersize=15, ls='none', alpha=0.9, linewidth=4, transform=trans3) 


plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, prop={'size': 22})
plt.xlabel("Monitoring Stations", fontsize=26)
plt.xticks(fontsize=24)
plt.ylabel("RMSE", fontsize=26)
plt.yticks(fontsize=24)
plt.show()
